# %%
#list
n = [9.5,8.0,7.0,10.0]
print(n[0])
print(n[len(n)-1])
n.append(9.0)
print(n)
n.sort()
print(n)
# Out:
# 9.5
# 10.0
# [9.5, 8.0, 7.0, 10.0, 9.0]
# [7.0, 8.0, 9.0, 9.5, 10.0]

# %%
#tuple
A=(3,4)
for (a,b) in enumerate (A):
    print(a,b)
list=[1,2,3]
tup=tuple(list)
print(tup)
# Out:
# 0 3
# 1 4
# (1, 2, 3)

# %%
list=[1,3,5,7,9,5,8,4]
def sum(i):
    for i in range(list):
        sum=sum+i
        tb=sum/len(list)
    return(tb)
print(tb)
# Out:
# 0

# %%
#dictionary
pr={'name':'An','major':'CS'}
pr['year']='3'
print(pr)
for k,v in pr.items():
    print(k,v)
def dem(s):
# Out:
# {'name': 'An', 'major': 'CS', 'year': '3'}
# name An
# major CS
# year 3

# %%
def fib(n):
    for i in range(n):
        a, b = b, a+b
        return(a, b)
n=int(input())
print(fib(n))
# Out:
#  4
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[15], line 6
#       4         return(a, b)
#       5 n=int(input())
# ----> 6 print(fib(n))
#
# Cell In[15], line 3, in fib(n)
#       1 def fib(n):
#       2     for i in range(n):
# ----> 3         a, b = b, a+b
#       4         return(a, b)
#
# UnboundLocalError: cannot access local variable 'b' where it is not associated with a value
