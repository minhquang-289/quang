# %%
#Bai tap tuan 4
#W4A1
sum=0
for i in range(1,1001,1):
     sum = sum + i
print("Tong cac so tu 1 den 1000 la:",sum)
# Out:
# Tong cac so tu 1 den 1000 la: 500500

# %%
#W4A1
sum = 0
n = 0
while n <= 1000:
    sum = sum+n
    n=n+1
print("Tong cac so tu 1 den 1000 la:",sum)
# Out:
# Tong cac so tu 1 den 1000 la: 500500

# %%
#W4A2
import math
while True:
    n = int(input("Nhap vao 1 so:"))
    if n > 0:
        break
def so_nguyen_to(n):
    if n < 2:
        print("Day khong phai la so nguyen to")
    for i in range (2,math.sqrt(n)+1):
        if n % i ==0:
            return False
        else:
            return True
if True :
    print("Day la so nguyen to")
else:
    print("Day khong phai la so nguyen to")
# Out:
# Nhap vao 1 so: 10000001
# Day la so nguyen to

# %%
#W4A3
n = int(input("Nhap vao 1 so:"))
sum = 1
for i in range(1,n +1):
    sum = sum*i
print("Ket qua la:",sum)
# Out:
# Nhap vao 1 so: 12
# Ket qua la: 479001600

# %%
#W4A4
import math
n= int(input("Nhap vao 1 so nguyen"))
a=int(math.log(n,10)) + 1
print("So chu so cua a la:",a)
# Out:
# Nhap vao 1 so nguyen 123456
# So chu so cua a la: 6

# %%
#W4A4
n = int(input("Nhap mot so:"))
a = 0
while n !=0:
    n = n // 10
    a = a+1
print("So chu so cua so do la:",a)
# Out:
# Nhap mot so: 123456
# So chu so cua so do la: 6

# %%
#W4A5
n = int(input("Nhap vao 1 so:"))
cout=0
flag = False
for i in range(1,n+1):
    a = int(input())
    if a==42:
        cout += 1
        flag = True 
        break
if True:
    print("I′ve found the meaning of life!")
else:
    print("It′s a joke!")
# Out:
# Nhap vao 1 so: 5
#  1
#  2
#  3
#  42
# I′ve found the meaning of life!

# %%
#W4A5
n= int(input("Nhap vao 1 so:"))
day_so=map(int,input(f"Nhap vao {n} so nguyen,cach nhau boi dau cach").split())
found=False
for x in day_so:
    if x == 42:
        found=True
        break
if True:
    print("I′ve found the meaning of life!")
else:
    print("It′s a joke!")
# Out:
# Nhap vao 1 so: 6
# Nhap vao 6 so nguyen,cach nhau boi dau cach 1 42 54 67 87 98
# I′ve found the meaning of life!

# %%
#W4A6
a,b=map(int,input("Nhap vao hai so a va b (a<=b):".split()))
for i in range(a,b+1):
    if i % i ==0:

# %%
#W4A7
import math
n = int(input("Nhap vao 1 so(>=2):"))
if n<2:
    print("Khong co uoc nguyen to")
else:
    for i in range(2,int(math.sqrt(n)+1)):
        while n % i ==0:
            n = n // i 
if n >1:
    print("Uoc nguyen to lon nhat cua so do la:",n)
# Out:
# Nhap vao 1 so(>=2): 91
# Uoc nguyen to lon nhat cua so do la: 13

# %%
#W4A8
n = int(input("Nhap vao mot so:"))
cout=0
x=0
a =n
while n !=0:
    x = x * 10 + n % 10
    n =n //10
if a ==x:
    print("Đây là số đối xứng")
else:
    print("Đây không phải là số đối xứng")
# Out:
# Nhap vao mot so: 1234
# Đây không phải là số đối xứng

# %%
#W4A11
n = int(input("Nhap vao 1 so:"))
cout = 0
for i in range(2,n+1,2):
    if n % i == 0:
        cout +=1
print("So uoc chan cua n la:",cout)
# Out:
# Nhap vao 1 so: 8
# So uoc chan cua n la: 3

# %%
#W4A12
x = int(input("So tien goc:"))
n = int(input("So thang muon gui"))
for i in range(n):
    x = x * 1.007
print("So tien nhan duoc:",round(x,0))
# Out:
# So tien goc: 200000
# So thang muon gui 8
# So tien nhan duoc: 211478.0

# %%
#W4A13
a = int(input())
b = int(input())
tonga = 0
tongb = 0
for i in range (1,a):
    if a % i ==0:
        tonga += i
for i in range (1,b):
    if b % i ==0:
        tongb += i
if tonga == b and tongb == a:
    print("true")
else:
    print("false")
# Out:
#  220
#  284
# true

# %%
m,n= map(int,input("Nhap vao hai so:").split())
a = 0
for i in range(1,min(m,n)+1):
    if m % i ==0 and n % i==0:
        a = i
print(i)
# Out:
# Nhap vao hai so: 36 6
# 6

# %%
# Out:
#  100
# 4950

# %%
#W4A10
#Nhập vào số nguyên dương n. Tìm số x trong [1, n] có độ dài dãy Collatz lớn nhất
#và in ra x cùng độ dài dãy tương ứng (x L). Nếu có nhiều số cùng độ dài, chọn số
#nhỏ nhất."
def cout(n):
    cout = 0
    while n !=1:
        if n % 2 ==0:
            n = n/2
        else:
            n = n*3+1
        cout = cout + 1
    return cout
if __name__== "__main__":
 for i in range(1, n+1):
    dem =0
    if cout(i)>dem:
        dem = cout(i)
print(dem)
# Out:
# 19

# %%
#W4A9
#Nhập vào số nguyên dương n. In ra tất cả các số chính phương ≤ n có các chữ số
#đôi một khác nhau (in theo thứ tự tăng dần, cùng hàng, cách nhau bởi một dấu
#cách). Nếu không có, in ra (no number).
import math
def scp(a):
    if int(math.sqrt(a)) == math.sqrt(a):
        return True
    return False

if __name__=='__main__':
    n=int(input())
    for a in range(1,n+1):
        if scp(a):
            print(a,end=' ')
# Out:
# 1 4 9 16 25 36 49 64 81

# %%
#tim ucln va bcnn
import math
def ucd(a,b):
    while b:
        a,b=b,a%b
    return a
def lcm(a,b):
    return a*b//ucd(a,b)

if __name__=='__main__':
    a,b=map(int,input().split())
