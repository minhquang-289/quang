# %%
#HW1
a=int(input())
so_nguyen=2*a
print(so_nguyen)
# Out:
#  3
# 6

# %%
#HW2
a,b=map(float,input().split())
dien_tich=a*b-(a/2)*(a/2)*3.14
round(dien_tich,2)
print(dien_tich)
# Out:
#  3 4
# 4.935

# %%
#HW3
n =input("Hay nhap vao mot kitu:")
if n>='A' and n<='Z':
    n = chr(ord(n) + 32)
    print("Chu thuong tuong ung la:",n)
elif n>='a' and n<='z':
    n = chr(ord(n) - 32)
    print("Chu hoa tuong ung la:",n)
else:
    print("Du lieu khong hop le")
# Out:
# Hay nhap vao mot kitu: a
# Chu hoa tuong ung la: A

# %%
#HW4
c = input("Hay nhap vao mot ki tu")
if c>='A' and c<= 'Z':
    print("{c} là kí tu alphabet",c)
elif c>='a' and c<='z':
    print("{c} là kí tu alphabet",c)
else:
    print("{c}không phải là kí tự alphabet")
# Out:
# Hay nhap vao mot ki tu 8
# {c}không phải là kí tự alphabet

# %%
#HW5
c=input("Hay nhap vao mot ki tu:")
if c>'A' and c<='Z':
    n = chr(ord(c)+32)
    a = ord(n)-1
    print("Chu cai do la:",chr(a))
elif c == 'A':
    print("Khong co chu cai nao")
else:
    print("Du lieu khong hop le")
# Out:
# Hay nhap vao mot ki tu: H
# Chu cai do la: g

# %%
#HW6
import math
a,b,c = map(float,input("Hay nhap vao ba so bat ky:").split())
if a < b + c and b < a + c and c < a + b:
    p = (a + b + c)/2
    s = math.sqrt(p * (p-a) * (p-b) * (p-c))
    print("Dien tich cua tam giac la:",round(s,1))
else:
    print("Khong phai 3 canh cua tam giac")
# Out:
# Hay nhap vao ba so bat ky: 4 5 6
# Dien tich cua tam giac la: 9.9

# %%
#HW7
a = input("Nhap vao mot chuoi cac chu cai thuong(=>20 chu cai):")
if len(a) >= 20 and a.islower():
   print("Chu cai thu 5 la:", a[4])
   print("Chu cai thu 9 la:", a[8])
else:
   print("Du lieu khong hop le.Vui long nhap lai")
# Out:
# Nhap vao mot chuoi cac chu cai thuong(=>20 chu cai): qwertyuiopasdfghjklz
# Chu cai thu 5 la: t
# Chu cai thu 9 la: o

# %%
ten = input("Ten chu ho: ")
chi_so_cu = int(input("Chi so thang truoc: "))
chi_so_moi = int(input("Chi so thang nay: "))
so_dien = chi_so_moi - chi_so_cu
if so_dien < 0:
    print("Chỉ số mới phải lớn hơn hoặc bằng chỉ số cũ.")
else:
    if so_dien <= 50:
        tien_dien = so_dien * 1984
    elif so_dien <= 100:
        tien_dien = 50 * 1984 + (so_dien - 50) * 2050
    elif so_dien <= 200:
        tien_dien = 50 * 1984 + 50 * 2050 + (so_dien - 100) * 2380
    elif so_dien <= 300:
        tien_dien = 50 * 1984 + 50 * 2050 + 100 * 2380 + (so_dien - 200) * 2998
    elif so_dien <= 400:
        tien_dien = (50 * 1984 + 50 * 2050 + 100 * 2380 +
                     100 * 2998 + (so_dien - 300) * 3350)
    else:
        tien_dien = (50 * 1984 + 50 * 2050 + 100 * 2380 +
                     100 * 2998 + 100 * 3350 + (so_dien - 400) * 3460)
    vat = tien_dien * 0.08
    tong_tien = round(tien_dien + vat)
    print("Ho va Ten:", ten)
    print("Tien phai tra la:", tong_tien)
# Out:
# Ten chu ho:  Phan Minh Quang
# Chi so thang truoc:  298
# Chi so thang nay:  350
# Ho va Ten: Phan Minh Quang
# Tien phai tra la: 111564

# %%
#HW9
a = int(input("Hay nhap mot so:"))
if a % 2 == 0:
    print("So chan")
else:
    print("So le")
# Out:
# Hay nhap mot so: 3
# So le

# %%
#HW10
a = int(input("Hay nhap mot so nguyen:"))
if a % 10 == 5:
    print("True")
else:
    print("False")
# Out:
# Hay nhap mot so nguyen 65
# True

# %%
#HW11
a = int(input("Hay nhap vao 1 so"))
if a % 15 == 0:
    print("True")
else:
    print("False")
# Out:
# Hay nhap vao 1 so 15
# True

# %%
#HW12
a = int(input("Hay nhap nam sinh:"))
n = 2025 - a
if n >= 18:
    print("Du tuoi di bau cu")
else:
    print("Khong du tuoi di bau cu")
# Out:
# Hay nhap nam sinh: 2007
# Du tuoi di bau cu

# %%
#HW13
a,b=map(int,input("Hay nhap 2 so bat ky:").split())
if a > b:
    print(a)
elif b > a:
    print(b)
else:
    print("Hai so bang nhau")
# Out:
# Hay nhap 2 so bat ky: 4 3
# 4

# %%
#HW14
char=input("Hay nhap mot ki tu:")
if char.isalpha():
    print("Day la mot chu cai")
elif char.isdigit():
    print("Day la mot so")
else:
    print("Du lieu khong hop le")
# Out:
# Hay nhap mot ki tu: 1
# Day la mot so

# %%
#HW15
a = float(input("Hay nhap diem cua ban"))
if a >= 8:
    print("Gioi")
elif a >= 6.5 and a < 8:
    print("Kha")
elif a >= 5 and a < 6.5:
    print("Trung binh")
elif a < 5:
    print("Yeu")
else:
    print("Du lieu khong hop le")
# Out:
# Hay nhap diem cua ban 8
# Gioi

# %%
#HW16
a = int(input("Hay nhap so nam"))
if a % 400 == 0 or a % 4 == 0:
    print("Nam nhuan")
elif a % 100 != 0:
    print("Nam nhuan")
else:
    print("Khong phai nam nhuan")
# Out:
# Hay nhap so nam 2089
# Nam nhuan

# %%
#HW17
a = float(input("Hay nhap diem cua ban"))
if a >= 4:
    print("Qua môn")
else:
    print("Học lại")
# Out:
# Hay nhap diem cua ban 3.99
# Học lại

# %%
#HW18
a = int(input("Hay nhap nam sinh cua ban:"))
b = 2025 - a
print("So tuoi cua ban la:",b)
if b >= 18:
    print("Ban da du 18")
elif b < 18:
    print("Ban chua du 18")
else:
    print("Du lieu khong hop le")
# Out:
# Hay nhap nam sinh cua ban: 2020
# So tuoi cua ban la: 5
# Ban chua du 18
